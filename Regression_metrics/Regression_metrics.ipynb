# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('placement.csv')

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
plt.scatter(df['cgpa'], df['package'])
plt.xlabel('Cgpa')
plt.ylabel('Package')
# Out:
# Text(0, 0.5, 'Package')

# %%
X = df.iloc[:,0:1]
y = df.iloc[:,-1]

# %%
y
# Out:
# 0      3.26
# 1      1.98
# 2      3.25
# 3      3.67
# 4      3.57
#        ...
# 195    2.46
# 196    2.57
# 197    3.24
# 198    3.96
# 199    2.33
# Name: package, Length: 200, dtype: float64

# %%
X
# Out:
#      cgpa
# 0    6.89
# 1    5.12
# 2    7.82
# 3    7.42
# 4    6.94
# ..    ...
# 195  6.93
# 196  5.89
# 197  7.21
# 198  7.63
# 199  6.22
#
# [200 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(df['cgpa'], df['package'])
plt.plot(X_train, lr.predict(X_train), color="red")
plt.xlabel('Cgpa')
plt.ylabel('Package in lpa')
# Out:
# Text(0, 0.5, 'Package in lpa')

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
y_pred = lr.predict(X_test)

# %%
y_test.values
# Out:
# array([4.1 , 3.49, 2.08, 2.33, 1.94, 1.48, 1.86, 3.09, 4.21, 2.87, 3.65,
#        4.  , 2.89, 2.6 , 2.99, 3.25, 1.86, 3.67, 2.37, 3.42, 2.48, 3.65,
#        2.6 , 2.83, 4.08, 2.56, 3.58, 3.81, 4.09, 2.01, 3.63, 2.92, 3.51,
#        1.94, 2.21, 3.34, 3.34, 3.23, 2.01, 2.61, 3.13, 3.91, 2.25, 2.3 ,
#        4.06, 3.18, 2.7 , 2.49, 3.15, 2.99, 4.08, 4.14, 2.6 , 2.44, 2.71,
#        2.72, 1.63, 2.31, 2.51, 3.5 ])

# %%
print("Mean Absolute Error", mean_absolute_error(y_test, y_pred))
# Out:
# Mean Absolute Error 0.28749100679609296

# %%
print("Mean Squared Error", mean_squared_error(y_test, y_pred))
# Out:
# Mean Squared Error 0.11858895151249163

# %%
print("Root Mean Squared Error", np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# Root Mean Squared Error 0.3443674658159386

# %%
print("R2 Score", r2_score(y_test,y_pred))
r2 = r2_score(y_test,y_pred)
# Out:
# R2 Score 0.7736419609402847

# %%
#Adjusted r2 score
X_test.shape
# Out:
# (60, 1)

# %%
1 - ((1-r2)*(60-1)/(60-1-1))
# Out:
# 0.7697392361289103
